# %% [markdown]
# function identification **word()**
# * print()
# * len()
# * dir()
# * type()
#
# ### data type
# * int  1
# * float 2.0
# * string "pakistan"
# * string 'pakistan'
# * string ''' pakistan '''
# * string """ pakistan """
#
# https://www.markdownguide.org/cheat-sheet/

# %%
print()

# %%
print("Pakistan") #pass string data type value
# Out:
# Pakistan

# %%
print('pakistan') #pass string data type value
# Out:
# pakistan

# %%
print('''pakistan''')
# Out:
# pakistan

# %%
print("""pakistan""")
# Out:
# pakistan

# %%
print(2)
# Out:
# 2

# %%
print(7.9)
# Out:
# 7.9

# %%
print("Pakistan","China",20, 7.20)
# Out:
# Pakistan China 20 7.2

# %% [markdown]
# # Variable

# %% [raw]
# variable_name = variable_value

# %%
print(200)
print("pakistan")
print(200)
print("We love our country")
print(200)
# Out:
# 200
# pakistan
# 200
# We love our country
# 200

# %%
print(200);print("pakistan");print(200);print("We love our country");print(200)
# Out:
# 200
# pakistan
# 200
# We love our country
# 200

# %%
print(300)
print("pakistan")
print(300)
print("We love our country")
print(300)
# Out:
# 300
# pakistan
# 300
# We love our country
# 300

# %%
# variable_name = variable_value
a = 500
print(a)
print("pakistan")
print(a)
print("We love our country")
print(a)
# Out:
# 500
# pakistan
# 500
# We love our country
# 500

# %%
# variable_name = variable_value
a = 500

print(a,"pakistan",a,"We love our country",a)
# Out:
# 500 pakistan 500 We love our country 500

# %%
# variable_name = variable_value
a = 500

print(a,"pakistan",a,"We love our country",a, sep='\n')
# Out:
# 500
# pakistan
# 500
# We love our country
# 500

# %%
name = "Muhammad Qasim"
father_name = "Muhammad Aslam"
weight = 84



print("NED Student Idientity Card")
print("Name:",name)
print("Father's Name", father_name)
print("Weight",weight)
# Out:
# NED Student Idientity Card
# Name: Muhammad Qasim
# Father's Name Muhammad Aslam
# Weight 84

# %%
name = "Muhammad Qasim"
print(name) # show variable value
print(type(name)) # show variable data type class
print(id(name)) # show memory address
# Out:
# Muhammad Qasim
# <class 'str'>
# 139757902105712

# %%
weight = 84
print(weight) # show variable value
print(type(weight)) # show variable data type class
print(id(weight)) # show memory address
# Out:
# 84
# <class 'int'>
# 7397312

# %%
weight = 84.5
print(weight) # show variable value
print(type(weight)) # show variable data type class
print(id(weight)) # show memory address
# Out:
# 84.5
# <class 'float'>
# 139757924995504

# %%
a = True
print(a) # show variable value
print(type(a)) # show variable data type class
print(id(a)) # show memory address
# Out:
# True
# <class 'bool'>
# 7271584

# %%
a = False
print(a) # show variable value
print(type(a)) # show variable data type class
print(id(a)) # show memory address
# Out:
# False
# <class 'bool'>
# 7271552

# %%
a = [1,2,3]
print(a) # show variable value
print(type(a)) # show variable data type class
print(id(a)) # show memory address
# Out:
# [1, 2, 3]
# <class 'list'>
# 139757910550560

# %%
a = (1,2,3)
print(a) # show variable value
print(type(a)) # show variable data type class
print(id(a)) # show memory address
# Out:
# (1, 2, 3)
# <class 'tuple'>
# 139757909488576

# %%
a = {'name':'qasim'}
print(a) # show variable value
print(type(a)) # show variable data type class
print(id(a)) # show memory address
# Out:
# {'name': 'qasim'}
# <class 'dict'>
# 139757909542144

# %% [markdown]
# # String Data types with variable and text formation

# %%
a = "Pakistan zinda bad" # single line string


print(type(a))
print(a)
# Out:
# <class 'str'>
# Pakistan zinda bad

# %%
a = 'Pakistan zinda bad' # signle line string


print(type(a))
print(a)
# Out:
# <class 'str'>
# Pakistan zinda bad

# %%
# multiline string
a = """
hello world
Pakistan zinda bad
We love our country!
"""

print(type(a))
print(a)
# Out:
# <class 'str'>
#
# hello world
# Pakistan zinda bad
# We love our country!

# %%
a = 'Father's Name'
# Out:
#   File "<ipython-input-43-f38542d16676>", line 1
#     a = 'Father's Name
#                 ^
# SyntaxError: invalid syntax

# %%
a = "Father's Name"
print(type(a))
print(a)
# Out:
# <class 'str'>
# Father's Name

# %%
a = 'Father"s Name'
print(type(a))
print(a)
# Out:
# <class 'str'>
# Father"s Name

# %%
a = 'Father\'s Name' # convert ' special charater to normal character
b = "Father\"s Name"

print(a)
print(b)
# Out:
# Father's Name
# Father"s Name

# %%
id_card = "NED University\nStudent Name:Muhammad Qasim\nFather's Name:Muhammad Aslam"

print(type(id_card))
print(id_card)
# Out:
# <class 'str'>
# NED University
# Student Name:Muhammad Qasim
# Father's Name:Muhammad Aslam

# %%
id_card = """NED University
Student Name:Muhammad Qasim
Father's Name:Muhammad Aslam"""

print(type(id_card))
print(id_card)
# Out:
# <class 'str'>
# NED University
# Student Name:Muhammad Qasim
# Father's Name:Muhammad Aslam

# %%
id_card = '''NED University
Student Name:Muhammad Qasim
Father's Name:Muhammad Aslam'''

print(type(id_card))
print(id_card)
# Out:
# <class 'str'>
# NED University
# Student Name:Muhammad Qasim
# Father's Name:Muhammad Aslam

# %%
id_card = 'NED University
Student Name:Muhammad Qasim
Father's Name:Muhammad Aslam'

print(type(id_card))
print(id_card)
# Out:
#   File "<ipython-input-56-49cc94b7d0ad>", line 1
#     id_card = 'NED University
#                              ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ### Concatination

# %%
fname = "Muhammad"
lname = "Qasim"

full_name = fname + lname
print(full_name)
# Out:
# MuhammadQasim

# %%
fname = "Muhammad"
lname = "Qasim"

full_name = fname +" "+ lname
print(full_name)
# Out:
# Muhammad Qasim

# %%
age = 30
name = "Qasim"

result = "Student Name: "+name+", "+age 


print(result)
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-62-2b310e322599> in <module>
#       2 name = "Qasim"
#       3
# ----> 4 result = "Student Name: "+name+", "+age
#       5
#       6
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 30
name = "Qasim"

result = "Student Name: "+name+", "+str(age)


print(result)
# Out:
# Student Name: Qasim, 30

# %%
"1" + "1"
# Out:
# '11'

# %%
1 + 1
# Out:
# 2

# %%
"1" + 1
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-65-ec358fc6499a> in <module>
# ----> 1 "1" + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
"1" + str(1)
# Out:
# '11'

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
print(type(str(1))) # type casting = Number to string
# Out:
# <class 'str'>

# %%
fname = "Muhammad"
lname = "Qasim"
weight = 84
age = 30

id_card = "NED University\nStudent Name: "+fname+" "+lname+"\nAge: "+age

print(id_card)
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-73-77da08f14e76> in <module>
#       4 age = 30
#       5
# ----> 6 id_card = "NED University\nStudent Name: "+fname+" "+lname+"\nAge: "+age
#       7
#       8 print(id_card)
#
# TypeError: can only concatenate str (not "int") to str

# %%
fname = "Muhammad"
lname = "Qasim"
age = 30

id_card = "NED University\nStudent Name: "+fname+" "+lname+"\nAge: "+str(age)

print(id_card)
# Out:
# NED University
# Student Name: Muhammad Qasim
# Age: 30
